# %%
#to understand print
print("Hello World")
# Out:
# Hello World

# %%
if(10%2==0):
    print("even")
# Out:
# even

# %%
print(3)
# Out:
# 3

# %%
print("arun")
print(28)
print(25+65)
# Out:
# arun
# 28
# 90

# %%
print("Hello World")
print("Have a good day")
print("learn python well")
# Out:
# Hello World
# Have a good day
# learn python well

# %%
print("Hello",end=" ")
print("world")
# Out:
# Hello world

# %%
print("Radhaa is",35,"years old")
# Out:
# Radhaa is 35 years old

# %%
#single line comment
""" 
multiline
comment
"""
print("Hello")
# Out:
# Hello

# %%
x=4 
y="Arun"
print(y)
print(x)
# Out:
# Arun
# 4

# %%
a=4
A="REEMA"
print(a)
print(A)
# Out:
# 4
# REEMA

# %%
#multiple values to multiple variables
x,y,z="X","Y","Z"
print(x,z)
# Out:
# X Z

# %%
x=y=z="chaitanya"
print(x)
# Out:
# chaitanya

# %%
x="Hello"
y="Joseph"
print(x,y)
# Out:
# Hello Joseph

# %%
x="Ram" #gloobal variable
def func():
    print("hello",x)
func()
# Out:
# hello Ram

# %%
y="Ram" #global
def my():
    y="Shyam" #local
    print("hello",y)
my()
# Out:
# hello Shyam

# %%
x="Ram"
def learn():
    global x
    x="Shyam"
learn()
print("hi",x)
# Out:
# hi Shyam

# %%
#type()
x=6.006
y="string"
s=85
r=True
print(type(x))
print(type(y))
print(type(s))
print(type(r))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
#dataypes
x="Python"
y=20
m=20.39
n=1j
print(type(x))
print(type(y))
print(type(m))
print(type(n))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=["a","b","c"]
y=("m","n")
m={"a":1,"b":2}
n={"m","n","o"}
print(type(x))
print(type(y))
print(type(m))
print(type(n))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>

# %%
x=range(5)
print(x)
# Out:
# range(0, 5)

# %%
x=9
y=float(x)
print(x)
print(y)
# Out:
# 9
# 9.0

# %%
x=int(9.08)
print(x)
# Out:
# 9

# %%
y=str(8)
print(type(y))
# Out:
# <class 'str'>

# %%
#strings
a="apple"
print(a[4])
# Out:
# e

# %%
b="banana"
for x in b:
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
#len()
c="cartoon"
print(len(c))
# Out:
# 7

# %%
#in
o="I am busy tonight"
print('busy'in o)
# Out:
# True

# %%
#not in
o="I am busy tonight"
if('an'not in o):
    print("hey")
print('am' in o)
# Out:
# hey
# True

# %%
#slicing()
a="apple"
print(a[1:4])
print(a[1:3])
# Out:
# ppl
# pp

# %%
b="baeutiful"
print(b[:7])
print(b[3:])
# Out:
# baeutif
# utiful

# %%
c="character"
print(c[-5:-2])
# Out:
# act

# %%
#upper
d="dumbell"
print(d.upper())
# Out:
# DUMBELL

# %%
#lower
d="DumBeLl"
print(d.lower())
# Out:
# dumbell

# %%
#strip
e=" egg          "
print(len(e))
d=e
print(d.strip())
# Out:
# 14
# egg

# %%
#replace
z="parrot is on table"
print(z.replace("table","chair"))
print(z.replace('o','z'))
# Out:
# parrot is on chair
# parrzt is zn table

# %%
#split 
a="hello,hi,how are u,wanna talk"
print(a.split(","))
# Out:
# ['hello', 'hi', 'how are u', 'wanna talk']

# %%
#concatenation
a="sir"
b="vishwa"
c=a+b
print(c)
# Out:
# sirvishwa

# %%
a="sir"
b="vishwa"
c=a+" "+b
print(c)
# Out:
# sir vishwa

# %%
#f strings
age=90
c=f"my grandpa is {age} years old"
print(c)
# Out:
# my grandpa is 90 years old

# %%
age=90
c=f"we have differnce of {age-26} years btwn us"
print(c)
# Out:
# we have differnce of 64 years btwn us

# %%
#string methods
c="orange"
print(c.capitalize())

d="DOG"
print(d.casefold())

e="my elbow hurts"
print(e.center(1))


f="i am bold,i am tough,iam brave,i am short,i am strong"
print(f.count("am"))

g="i like fruits"
print(g.endswith("ts"))

h="i am scared"
print(h.find("scared"))

i="india is my country"
print(i.index('my'))

j="str8ung"
print(j.isalnum())
# Out:
# Orange
# dog
# my elbow hurts
# 5
# True
# 5
# 9
# True

# %%
print(bool("5"))
"""
Any string is True, except empty strings.

Any number is True, except 0.

Any list, tuple, set, and dictionary are True, except empty ones.
"""
# Out:
# True

# %%
#operator
#arithmetic
x=34
y=90
print(x+y) #add
print(x-y) #sub
print(x*y) #mul
print(x/y) #div
print(x%y) #rem
print(y**x) #power
print(x//y) #floor division
# Out:
# 124
# -56
# 3060
# 0.37777777777777777
# 34
# 2781283894436935112572857762317610000000000000000000000000000000000
# 0

# %%
#assignment operator
x=5
print(x)
x+=5
print(x)
x-=5
print(x)
x*=5
print(x)
x/=5
print(x)
x%=5
print(x)
x//=5
print(x)
x**=5
print(x)
# Out:
# 5
# 10
# 5
# 25
# 5.0
# 0.0
# 0.0
# 0.0

# %%
#comparision 
x=90
y=89
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
#logical
x=9000
y=9879
print(x>1000 and y<100000)
print(x>1000000 and y<10000)
print(x>1000 or y<100000)
print(x>1000000 or y<10000)
print(not(x>1000 or y<100000))
# Out:
# True
# False
# True
# True
# False

# %%
#identity operator
x=10
y=20
z=y
print(x is y)
print(y is z)
print(z is not x)
print(z is not y)
print(x==y)
# Out:
# False
# True
# True
# False
# False

# %%
#membership operator
m="I am late tonight"
print('busy'in m)
print('busy'not in m)
# Out:
# False
# True

# %%
#ternary,bitwise
#precedence

# %%
#list
names=["arya","amal","akshay"]
print(names)
# Out:
# ['arya', 'amal', 'akshay']

# %%
names=["arya","amal","akshay","arya"]
print(names)
# Out:
# ['arya', 'amal', 'akshay', 'arya']

# %%
names=["arya","amal","akshay","arya"]
print(len(names))
# Out:
# 4

# %%
collection=['w','arya',91,True]
print(collection)
print(type(collection))
# Out:
# ['w', 'arya', 91, True]
# <class 'list'>

# %%
name=list(("apple","banana")) #list constructor
print(name)
# Out:
# ['apple', 'banana']

# %%
items=['orange','apple','cherry','pine']
print(items[2])
# Out:
# cherry

# %%
items=['orange','apple','cherry','pine']
print(items[-3])
# Out:
# apple

# %%
items=['orange','apple','cherry','pine']
print(items[1:3])
# Out:
# ['apple', 'cherry']

# %%
items=['orange','apple','cherry','pine']
print(items[-3:-1])
# Out:
# ['apple', 'cherry']

# %%
items=['orange','apple','cherry','pine']
if "orange" in items:
    print("yessss")
# Out:
# yessss

# %%
collection=['w','arya',91,True]
collection[2]=74
print(collection)
# Out:
# ['w', 'arya', 74, True]

# %%
collection=['w','arya',91,True]
collection[2:4]=[43,"oii"]
print(collection)
# Out:
# ['w', 'arya', 43, 'oii']

# %%
items=['orange','apple','cherry','pine']
items.insert(2,"road")
print(items)
# Out:
# ['orange', 'apple', 'road', 'cherry', 'pine']

# %%
items=['orange','apple','cherry','pine']
items.append("pomo")
print(items)
# Out:
# ['orange', 'apple', 'cherry', 'pine', 'pomo']

# %%
items=['orange','apple','cherry','pine']
collection=['w','arya',91,True]
items.extend(collection)
print(items)
# Out:
# ['orange', 'apple', 'cherry', 'pine', 'w', 'arya', 91, True]

# %%
a=['orange', 'apple', 'cherry', 'pine', 'w', 'arya', 91, True]
a.remove("w")
print(a)
# Out:
# ['orange', 'apple', 'cherry', 'pine', 'arya', 91, True]

# %%
a=['orange', 'apple', 'cherry', 'pine', 'w', 'arya', 91, True]
a.pop(6)
print(a)
# Out:
# ['orange', 'apple', 'cherry', 'pine', 'w', 'arya', True]

# %%
items=['orange','apple','cherry','pine']
for i in items:
    print(i)
# Out:
# orange
# apple
# cherry
# pine

# %%
items=['orange','apple','cherry','pine']
for i in range(len(items)):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
items=['orange','apple','cherry','pine']
i=0
while(i<len(items)):
    print(items[i])
    i=i+1
# Out:
# orange
# apple
# cherry
# pine

# %%
items=['orange','apple','cherry','pine']
c=[ x for x in items]
print(c)
# Out:
# ['orange', 'apple', 'cherry', 'pine']

# %%
items=['orange','apple','cherry','pine']
items.sort()
print(items)
# Out:
# ['apple', 'cherry', 'orange', 'pine']

# %%
items=['orange','apple','cherry','pine']
items.sort(reverse=True)
print(items)
# Out:
# ['pine', 'orange', 'cherry', 'apple']

# %%
items=['orange','apple','cherry','pine']
items.reverse()
print(items)
# Out:
# ['pine', 'cherry', 'apple', 'orange']

# %%
items=['orange','apple','cherry','pine']
fruits=items.copy()
print(fruits)
# Out:
# ['orange', 'apple', 'cherry', 'pine']

# %%
items=['orange','apple','cherry','pine']
collection=['w','arya',91,True]
list=items+collection
print(list)
# Out:
# ['orange', 'apple', 'cherry', 'pine', 'w', 'arya', 91, True]

# %%
#tuple
tuple=("raj","ram","roy")
print(tuple)
# Out:
# ('raj', 'ram', 'roy')

# %%
tuple=("raj","ram","roy")
print(len(tuple))
# Out:
# 3

# %%
tup=("raj",89.0,True)
print(tup)
print(type(tup))
# Out:
# ('raj', 89.0, True)
# <class 'tuple'>

# %%
newt= tuple(("a","b","c"))
print(newt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 newt= tuple(("a","b","c"))
#       2 print(newt)
#
# TypeError: 'tuple' object is not callable

# %%
tuple=("raj","ram","roy")
print(tuple[1])
# Out:
# ram

# %%
tuple=("raj","ram","roy")
print(tuple[-2])
# Out:
# ram

# %%
tuple=("raj","ram","roy")
print(tuple[1:3])
# Out:
# ('ram', 'roy')

# %%
tuple=("raj","ram","roy")
if "rain" in tuple:
    print("oii")

# %%
tuple=("raj","ram","roy")
tuple[2]="ashu"
print(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[177], line 2
#       1 tuple=("raj","ram","roy")
# ----> 2 tuple[2]="ashu"
#       3 print(tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple=("raj","ram","roy")
tup=("a","b","c")
new=tuple+tup
print(new)
# Out:
# ('raj', 'ram', 'roy', 'a', 'b', 'c')

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[185], line 2
#       1 x = ("apple", "banana", "cherry")
# ----> 2 y = list(x)
#       3 y[1] = "kiwi"
#       4 x = tuple(y)
#
# TypeError: 'list' object is not callable

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
#set
claass={"a","b","c"}
print(claass)
print(type(claass))
# Out:
# {'a', 'c', 'b'}
# <class 'set'>

# %%
vow={"a","e","i","o","u","a"}
print(vow)
# Out:
# {'e', 'i', 'a', 'u', 'o'}

# %%
junk={"star",56,True,900.87}
print(junk)
# Out:
# {56, True, 900.87, 'star'}

# %%
junk={"star",56,True,900.87}
print(len(junk))
# Out:
# 4

# %%
junk={"star",56,True,900.87}
for x in junk:
    print(x)
# Out:
# 56
# True
# 900.87
# star

# %%
junk={"star",56,True,900.87}
if "star" in junk:
    print("star")
# Out:
# star

# %%
junk={"star",56,True,900.87}
junk.add("rose")
print(junk)
# Out:
# {True, 900.87, 'rose', 'star', 56}

# %%
junk={"star",56,True,900.87}
liquid={"juice","wster","star",1}
junk.update(liquid)
print(junk)
# Out:
# {True, 900.87, 'star', 'wster', 56, 'juice'}

# %%
liquid={"juice","wster","star",1}
liquid.remove(1)
print(liquid)
# Out:
# {'juice', 'wster', 'star'}

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# apple
# banana

# %%
char= {"a", "b", "c"}
num= {1, 2, 3}

mer = char.union(num)

print(mer)
# Out:
# {1, 2, 3, 'a', 'c', 'b'}

# %%
char= {"a", "b", "c"}
num= {1, 2, 3}
mer =char|num
print(mer)
# Out:
# {1, 2, 3, 'a', 'c', 'b'}

# %%
char= {"a", "b", "c"}
num= {1, 2, 3}

mer = char.intersection(num)

print(mer)
# Out:
# set()

# %%
char= {"a", "b", "c"}
num= {1, 2, 3}

mer = char & num

print(mer)
# Out:
# set()

# %%
char= {"a", "b", "c"}
num= {1, 2, 3}

mer = char.difference(num)

print(mer)
# Out:
# {'a', 'c', 'b'}

# %%
#dictionary
student={
    "name":"john",
    "id":104
}
print(student)
print(type(student))
# Out:
# {'name': 'john', 'id': 104}
# <class 'dict'>

# %%
student={
    "name":"john",
    "id":104
}
print(student["id"])
print(len(student))
print(type(student))
x=student.get("name")
print(x)
y=student.keys()
print(y)
z=student.values()
print(z)
a=student.items()
print(a)
# Out:
# 104
# 2
# <class 'dict'>
# john
# dict_keys(['name', 'id'])
# dict_values(['john', 104])
# dict_items([('name', 'john'), ('id', 104)])

# %%
student={
    "name":"john",
    "id":104
}
student.update({"year":2024})
print(student)
# Out:
# {'name': 'john', 'id': 104, 'year': 2024}

# %%
student={
    "name":"john",
    "id":104
}
student.pop("name")
print(student)
# Out:
# {'id': 104}

# %%
student={
    "name":"john",
    "id":104
}
for x in student:
    print(x)
# Out:
# name
# id
